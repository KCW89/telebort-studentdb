# %%
import os
import pandas as pd

# Now read the file
df2 = pd.read_csv('wideformatextracted.csv')
print('Success! Shape:', df2.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 5
#       2 import pandas as pd
#       4 # Now read the file
# ----> 5 df2 = pd.read_csv('wideformat-extracted-row1.csv')
#       6 print('Success! Shape:', df2.shape)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
# ...

# %%
import os
os.chdir('sandbox-4.5/prosessing-1st-row')
df2 = pd.read_csv("2.extracted-row1.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 import os
# ----> 2 os.chdir('sandbox-4.5/prosessing-1st-row')
#       3 df2 = pd.read_csv("2.extracted-row1.csv")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'sandbox-4.5/prosessing-1st-row'

# %%
df = pd.read_csv("CurrentSandbox.csv")

# %%
df
# Out:
#          Date Attendance CSguru / Interns   Session Submission Link/ Score  \
# 0  28/06/2025   Attended          Soumiya        11                  Numpy
#
#                 Lesson Exit ticket scores Progress\r\n(1 to 5)      Date.1  \
# 0  L9 Numpy: COMPLETED                  -                ★★★★★  21/06/2025
#
#   Attendance.1  ... Exit ticket scores.58  Progress\r\n(1 to 5).58 Date.59  \
# 0     Attended  ...                     -                        -       -
#
#   Attendance.59 CSguru / Interns .59 Session.59 Submission Link/ Score.59  \
# 0             -                    -          -                         -
#
#   Lesson.58 Exit ticket scores.59  Progress\r\n(1 to 5).59
# 0         -                     -                        -
#
# [1 rows x 480 columns]

# %%
df1 = pd.read_csv("sandbox.csv")
df1
# Out:
#            Date Attendance CSguru / Interns  Session  \
# 0    28/06/2025   No Class          Soumiya       26
# 1    28/06/2025   Attended          Soumiya       11
# 2    28/06/2025   Attended          Soumiya        4
# 3    28/06/2025   Attended          Soumiya       25
# 4    28/06/2025   Attended          Soumiya       21
# ..          ...        ...               ...     ...
# 106  29/06/2025   Attended            Rahmat      10
# 107  29/06/2025   Attended            Rahmat      25
# 108  29/06/2025   Attended             Puvin      30
# 109  29/06/2025   Attended            Rahmat      13
# 110  29/06/2025   Attended            Rahmat      16
#
#                                 Submission Link/ Score  \
# 0                                                    -
# 1                                                Numpy
# 2                                Conditional Statement
# 3    Final Project Proposal\nFinal project Submissi...
# ...

# %%
# Get the top 10 rightmost columns
rightmost_10 = df1.iloc[:, -10:]  # selects last 10 columns of every row

# Print the first few rows (e.g. top 5) of those columns
print(rightmost_10.head())
# Out:
#   Exit ticket scores.58 Progress\n(1 to 5).58 Date.59 Attendance.59  \
# 0                     -                     -       -             -
# 1                     -                     -       -             -
# 2                     -                     -       -             -
# 3                     -                     -       -             -
# 4                     -                     -       -             -
#
#   CSguru / Interns .59 Session.59 Submission Link/ Score.59 Lesson.58  \
# 0                    -          -                         -         -
# 1                    -          -                         -         -
# 2                    -          -                         -         -
# 3                    -          -                         -         -
# 4                    -          -                         -         -
#
#   Exit ticket scores.59 Progress\n(1 to 5).59
# 0                     -                     -
# ...
