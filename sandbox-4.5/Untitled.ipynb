# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
def analyze_sandbox_data():
    """
    Comprehensive analysis of the CurrentSandbox.csv file
    """
    print("=" * 60)
    print("CURRENT SANDBOX DATA ANALYSIS")
    print("=" * 60)
    
    # Read the CSV file
    try:
        df = pd.read_csv('CurrentSandbox.csv')
        print(f"✓ Successfully loaded CSV file with {len(df)} rows and {len(df.columns)} columns")
    except Exception as e:
        print(f"✗ Error reading CSV file: {e}")
        return
    
    # Basic file information
    print(f"\n📊 FILE OVERVIEW:")
    print(f"   • Total rows: {len(df)}")
    print(f"   • Total columns: {len(df.columns)}")
    print(f"   • File size: {df.memory_usage(deep=True).sum() / 1024:.2f} KB")
    print (df.shape())


if __name__ == "__main__":
    analyze_sandbox_data()
# Out:
# ============================================================
# CURRENT SANDBOX DATA ANALYSIS
# ============================================================
# ✓ Successfully loaded CSV file with 1 rows and 480 columns
#
# 📊 FILE OVERVIEW:
#    • Total rows: 1
#    • Total columns: 480
#    • File size: 28.31 KB
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 26
#      22     print (df.shape())
#      25 if __name__ == "__main__":
# ---> 26     analyze_sandbox_data()
#
# Cell In[29], line 22, in analyze_sandbox_data()
#      20 print(f"   • Total columns: {len(df.columns)}")
#      21 print(f"   • File size: {df.memory_usage(deep=True).sum() / 1024:.2f} KB")
# ---> 22 print (df.shape())
#
# TypeError: 'tuple' object is not callable

# %%
df.head()
# Out:
#          Date Attendance CSguru / Interns   Session Submission Link/ Score  \
# 0  28/06/2025   Attended          Soumiya      11.0                  Numpy
# 1         NaN        NaN               NaN      NaN                    NaN
# 2         NaN        NaN               NaN      NaN                    NaN
# 3         NaN        NaN               NaN      NaN                    NaN
# 4         NaN        NaN               NaN      NaN                    NaN
#
#                 Lesson Exit ticket scores Progress\n(1 to 5)      Date.1  \
# 0  L9 Numpy: COMPLETED                  -              ★★★★★  21/06/2025
# 1                  NaN                NaN                NaN         NaN
# 2                  NaN                NaN                NaN         NaN
# 3                  NaN                NaN                NaN         NaN
# 4                  NaN                NaN                NaN         NaN
#
#   Attendance.1  ... Exit ticket scores.58  Progress\n(1 to 5).58 Date.59  \
# 0     Attended  ...                     -                      -       -
# 1          NaN  ...                   NaN                    NaN     NaN
# 2          NaN  ...                   NaN                    NaN     NaN
# 3          NaN  ...                   NaN                    NaN     NaN
# 4          NaN  ...                   NaN                    NaN     NaN
#
#   Attendance.59 CSguru / Interns .59 Session.59 Submission Link/ Score.59  \
# 0             -                    -          -                         -
# 1           NaN                  NaN        NaN                       NaN
# 2           NaN                  NaN        NaN                       NaN
# 3           NaN                  NaN        NaN                       NaN
# 4           NaN                  NaN        NaN                       NaN
#
#   Lesson.58 Exit ticket scores.59  Progress\n(1 to 5).59
# 0         -                     -                      -
# 1       NaN                   NaN                    NaN
# 2       NaN                   NaN                    NaN
# 3       NaN                   NaN                    NaN
# 4       NaN                   NaN                    NaN
#
# [5 rows x 480 columns]

# %%
df.shape
# Out:
# (848, 480)
